# %%
from bs4 import BeautifulSoup as soup
import requests

URL = "https://twitter.com/elonmusk"

# %%
print(soup(requests.get("https://twitter.com/elonmusk").text, "html.parser").prettify())
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="en">
#  <meta charset="utf-8"/>
#  <meta content="width=device-width,initial-scale=1,maximum-scale=1,user-scalable=0,viewport-fit=cover" name="viewport"/>
#  <link href="//abs.twimg.com" rel="preconnect"/>
#  <link href="//abs.twimg.com" rel="dns-prefetch"/>
#  <link href="//api.twitter.com" rel="preconnect"/>
#  <link href="//api.twitter.com" rel="dns-prefetch"/>
#  <link href="//pbs.twimg.com" rel="preconnect"/>
#  <link href="//pbs.twimg.com" rel="dns-prefetch"/>
#  <link href="//t.co" rel="preconnect"/>
#  <link href="//t.co" rel="dns-prefetch"/>
#  <link href="//video.twimg.com" rel="preconnect"/>
#  <link href="//video.twimg.com" rel="dns-prefetch"/>
#  <link as="script" crossorigin="anonymous" href="https://abs.twimg.com/responsive-web/client-web-legacy/polyfills.5b86bb55.js" nonce="ZmVmNTY1OWEtODhlNi00ODViLWJhN2EtODEwYWM3YjU4ZThk" rel="preload"/>
# ...

# %% [markdown]
# As we can see, soup doesn't run JS and as a result it gets Twitter's no JS warning page. We'll have to use something like Selenium to make the request and extract the actual HTML for "https://twitter.com/elonmusk"

# %%
# This imports Selenium and sets up the Firefox/GeckoDriver browser driver
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.firefox.service import Service
from selenium.webdriver.support.ui import WebDriverWait
from webdriver_manager.firefox import GeckoDriverManager

driver = webdriver.Firefox(service=Service(GeckoDriverManager().install()))
# Out:
# ====== WebDriver manager ======
# Current firefox version is 96.0
# Get LATEST geckodriver version for 96.0 firefox
# There is no [linux64] geckodriver for browser  in cache
# Getting latest mozilla release info for v0.30.0
# Trying to download new driver from https://github.com/mozilla/geckodriver/releases/download/v0.30.0/geckodriver-v0.30.0-linux64.tar.gz
# Driver has been saved in cache [/home/lackshan/.wdm/drivers/geckodriver/linux64/v0.30.0]

# %%
driver.get(URL)
twitter_elm = driver.find_elements(By.CSS_SELECTOR, '[data-testid="tweet"]')

for tweet in twitter_elm:
    content = tweet.find_element(By.CSS_SELECTOR, 'div[lang]')
    print(content.text)

driver.quit()
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# File ~/Projects/crypto-tweet-tracker/venv/lib64/python3.9/site-packages/urllib3/connection.py:174, in HTTPConnection._new_conn(self)
#     173 try:
# --> 174     conn = connection.create_connection(
#     175         (self._dns_host, self.port), self.timeout, **extra_kw
#     176     )
#     178 except SocketTimeout:
#
# File ~/Projects/crypto-tweet-tracker/venv/lib64/python3.9/site-packages/urllib3/util/connection.py:95, in create_connection(address, timeout, source_address, socket_options)
#      94 if err is not None:
# ---> 95     raise err
#      97 raise socket.error("getaddrinfo returns an empty list")
#
# File ~/Projects/crypto-tweet-tracker/venv/lib64/python3.9/site-packages/urllib3/util/connection.py:85, in create_connection(address, timeout, source_address, socket_options)
#      84     sock.bind(source_address)
# ...
